# %%
# %matplotlib inline
from dataset import ImagenetteDataset
from utils import visualize_samples

# %%
dataset = ImagenetteDataset(
    csv_file='imagenette_dataset.csv',
    root_dir='train/',
)
visualize_samples(dataset, 'Train Sample')
